# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['BIDI4.SA','JBSS3.SA', 'ALPA4.SA', 'LREN3.SA', 'MGLU3.SA']

# %%
df = pd.DataFrame()
for t in tickers:
    df[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 344 entries, 2018-05-11 to 2019-09-30
# Data columns (total 5 columns):
# BIDI4.SA    344 non-null float64
# JBSS3.SA    344 non-null float64
# ALPA4.SA    344 non-null float64
# LREN3.SA    344 non-null float64
# MGLU3.SA    344 non-null float64
# dtypes: float64(5)
# memory usage: 16.1 KB

# %% [markdown]
# ## Normalization

# %%
df.iloc[0]
# Out:
# BIDI4.SA     2.666522
# JBSS3.SA     8.878992
# ALPA4.SA    11.641175
# LREN3.SA    28.329231
# MGLU3.SA    12.986046
# Name: 2018-05-11 00:00:00, dtype: float64

# %%
(df / df.iloc[0] * 100).plot(figsize=(15,6))
plt.show()

# %%
df.plot(figsize=(15,6))
plt.show()

# %% [markdown]
# ## Search methods

# %%
df.loc['2018-05-24']
df.iloc[0]

# %% [markdown]
# ## Simple Return

# %%
returns = (df/df.shift(1)) - 1
returns.head()
# Out:
#             BIDI4.SA  JBSS3.SA  ALPA4.SA  LREN3.SA  MGLU3.SA
# Date
# 2018-05-11       NaN       NaN       NaN       NaN       NaN
# 2018-05-14  0.002718  0.016892 -0.023665 -0.010306 -0.004602
# 2018-05-15 -0.009214  0.018826 -0.040859 -0.034395 -0.015534
# 2018-05-16  0.006564  0.023913  0.020939  0.014706  0.053904
# 2018-05-17 -0.000541 -0.013800 -0.024753 -0.021256 -0.025488

# %%
weights = np.array([0.30,0.20,0.15,0.15,0.20])

# %%
np.dot(returns, weights)
# Out:
# array([        nan, -0.00182224, -0.0133938 ,  0.0228793 , -0.01492131,
#        -0.00665964,  0.00884463,  0.02358678, -0.01020916,  0.00033638,
#        -0.00299143, -0.03036654, -0.00216383, -0.0109842 ,  0.01199832,
#         0.01912957, -0.03851865, -0.0252435 , -0.05081362,  0.02157073,
#         0.00643735,  0.02011727, -0.00317181,  0.00535081, -0.00747923,
#        -0.00823571,  0.01907018, -0.0084563 , -0.01628432,  0.0078688 ,
#         0.0016998 ,  0.00673384, -0.02585333,  0.01720952,  0.02553776,
#        -0.00619293, -0.00023757,  0.01469259, -0.00279825, -0.00634721,
#         0.0082986 , -0.01123756,  0.02279219,  0.02087254,  0.03375238,
#         0.02780182, -0.00680332, -0.0027299 ,  0.00866308, -0.0060309 ,
#         0.01979964,  0.00745027, -0.01246716, -0.0092367 , -0.00855518,
#        -0.01330306,  0.00685395, -0.00213235,  0.01766109,  0.00191116,
#         0.03527844,  0.02396376,  0.00652519, -0.00050974,  0.03460379,
#        -0.00533267, -0.00231879,  0.0251724 , -0.01223234,  0.01919774,
#        -0.00486832, -0.01122122,  0.00785419, -0.01128604, -0.01064432,
#        -0.02693589,  0.00818415,  0.01077917,  0.01108961,  0.00309977,
#         0.03340653,  0.01765791, -0.00576181,  0.00526091,  0.00196409,
#         0.0025115 ,  0.03383625, -0.00678665,  0.01859228, -0.01083807,
#        -0.01605359, -0.00361119, -0.03193878,  0.01803751,  0.01853033,
#         0.01442713,  0.0039777 , -0.01054269, -0.0028485 ,  0.00241967,
#        -0.00707934,  0.00665104,  0.01176885,  0.01337191, -0.00910912,
#        -0.00512999, -0.00836477,  0.01153426,  0.00783088,  0.01376193,
#         0.01631893,  0.01874971,  0.03772261,  0.0433756 ,  0.03286268,
#         0.01322568, -0.01513944, -0.01241276, -0.00908916,  0.01507838,
#         0.00385676,  0.00629072, -0.00518459,  0.01287602,  0.00640339,
#        -0.00324436, -0.00718261,  0.00995904,  0.00383877,  0.05509803,
#         0.0040085 ,  0.04822599,  0.00816392, -0.0235922 ,  0.02815077,
#         0.00484543,  0.04385844,  0.03198018,  0.01242474,  0.02331281,
#         0.00335153, -0.02683846, -0.00414275, -0.01684814,  0.0084739 ,
#         0.02799246, -0.01989501, -0.03136118, -0.01188726,  0.01482945,
#         0.02976054,  0.0231563 , -0.01304539,  0.00134596, -0.01527173,
#         0.01223605, -0.00140115, -0.01649347, -0.03651376, -0.02329114,
#         0.04107019, -0.00171995, -0.00723826,  0.02017118,  0.00072393,
#         0.01083536,  0.00805853,  0.01646879, -0.01332106,  0.01811503,
#         0.0034169 ,  0.00386536, -0.00214913,  0.00334382])

# %%
annual_return = returns.mean() * 250
annual_return
# Out:
# BIDI4.SA    1.583726
# JBSS3.SA    1.046920
# ALPA4.SA    0.655197
# LREN3.SA    0.470319
# MGLU3.SA    0.863101
# dtype: float64

# %%
np.dot(annual_return, weights)
# Out:
# 1.0259492371748502

# %%
portf_1 = '{}% ao ano'.format(round(np.dot(annual_return, weights),5) * 100)
portf_1
# Out:
# '102.595% ao ano'

# %%
weights_2 = np.array([0.20,0.20,0.25,0.25,0.20])

# %%
portf_2 = '{}% ao ano'.format(round(np.dot(annual_return, weights_2),5) * 100)
print(' pf1: {}\n pf2: {}'.format(portf_1,portf_2))
# Out:
#  pf1: 102.595% ao ano
#  pf2: 98.01299999999999% ao ano
